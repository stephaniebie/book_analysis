# %% [markdown]
# # Q1: Build a Table of Contents

# %%
from book_analysis import read_toc

# %%
technical_book_path = "../data/artificial_intelligence_a_modern_approach.txt"

# %%
tc = read_toc(technical_book_path, include_parts = True)
tc.children
# Out:
# [(1) Artificial Intelligence,
#  (2) Problem-solving,
#  (3) Knowledge, reasoning, and planning,
#  (4) Uncertain knowledge and reasoning,
#  (5) Machine Learning,
#  (6) Communicating, perceiving, and acting,
#  (7) Conclusions]

# %%
tc.height()
# Out:
# 4
