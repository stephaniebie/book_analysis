# %% [markdown]
# # Q1: Build a Table of Contents

# %%
from book_analysis import read_toc

# %%
technical_book_path = "../data/artificial_intelligence_a_modern_approach.txt"

# %%
tc = read_toc(technical_book_path, top_level=True)
tc.children
# Out:
# [(1) Artificial Intelligence,
#  (2) Problem-solving,
#  (3) Knowledge, reasoning, and planning,
#  (4) Uncertain knowledge and reasoning,
#  (5) Machine Learning,
#  (6) Communicating, perceiving, and acting,
#  (7) Conclusions]

# %%
tc.depth("Artificial Intelligence")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tc.depth("Artificial Intelligence")
#
# File ~\OneDrive - UCB-O365\Fall 2025\DTSC 5501\repos\book_analysis\src\book_analysis\toc.py:84, in Section.depth(self, title)
#      82 if self.title == title:
#      83     return 0
# ---> 84 return max([s.depth(title) for s in self.children]) + 1
#
# File ~\OneDrive - UCB-O365\Fall 2025\DTSC 5501\repos\book_analysis\src\book_analysis\toc.py:84, in Section.depth(self, title)
#      82 if self.title == title:
#      83     return 0
# ---> 84 return max([s.depth(title) for s in self.children]) + 1
#
#     [... skipping similar frames: Section.depth at line 84 (2 times)]
#
# File ~\OneDrive - UCB-O365\Fall 2025\DTSC 5501\repos\book_analysis\src\book_analysis\toc.py:84, in Section.depth(self, title)
#      82 if self.title == title:
#      83     return 0
# ...

# %%
tc.print(mode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tc.print(mode)
#
# NameError: name 'mode' is not defined

# %%
def depthFirstSearch(root):
    if root is None:
        return
    stack = []
    stack.append(root)
    while len(stack) > 0:
        print(stack[-1].title)
        cur_node = stack.pop(-1)
        for item in cur_node.children:
            stack.append(item)

# %%
depthFirstSearch(tc.children[0])

# %%
for child in tc.children:
    print(child)
    for childd in child.children:
        print("\t", childd)
